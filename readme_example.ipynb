# %% [markdown]
# # Basic usage (Readme example)

# %%
# RUN THIS IF RUNNING IN FORK
import os
import sys
sys.path.insert(0, os.path.abspath('../'))


# import required classes
from pyslope import (
    Slope,
    Material,
    Udl,
    LineLoad,
)

# %%
# RUN THIS CELL FIRST TO INITIALISE GOOGLE NOTEBOOK!!!!
# !pip install pyslope

# import required classes
from pyslope import (
    Slope,
    Material,
    Udl,
    LineLoad,
)
# Out:
# Requirement already satisfied: pyslope in /srv/conda/envs/notebook/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: colour in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (0.1.5)
# Requirement already satisfied: dj-database-url in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (2.1.0)
# Requirement already satisfied: django in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (5.0.3)
# Requirement already satisfied: gunicorn in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (21.2.0)
# Requirement already satisfied: kaleido==0.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (0.2.1)
# Requirement already satisfied: plotly in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (5.20.0)
# Requirement already satisfied: psycopg2-binary in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (2.9.9)
# Requirement already satisfied: pytest in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (8.1.1)
# Requirement already satisfied: pytest-cov in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (4.1.0)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (4.66.2)
# Requirement already satisfied: whitenoise in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pyslope) (6.6.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from dj-database-url->pyslope) (4.8.0)
# Requirement already satisfied: asgiref<4,>=3.7.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from django->pyslope) (3.7.2)
# Requirement already satisfied: sqlparse>=0.3.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from django->pyslope) (0.4.4)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.10/site-packages (from gunicorn->pyslope) (23.2)
# Requirement already satisfied: tenacity>=6.2.0 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from plotly->pyslope) (8.2.3)
# Requirement already satisfied: iniconfig in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest->pyslope) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest->pyslope) (1.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest->pyslope) (1.1.3)
# Requirement already satisfied: tomli>=1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest->pyslope) (2.0.1)
# Requirement already satisfied: coverage[toml]>=5.2.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pytest-cov->pyslope) (7.4.3)

# %%
from pyslope import (
    Slope,
    Material,
    Udl,
    LineLoad,
)

# %%
# Arbritrary example defined in README.md

# slope defined with height (m) of slope and angle (deg) or length (m) of slope,
# depending on which value is set and which is None.
s = Slope(height=3, angle=30, length=None)

# define a material with unit weight, friction angle, cohesion and depth from top
# of slope to bottom of layer. The model will automatically order units and if
# a material is the lowest it will be extended to the bottom of the model
m1 = Material(
    unit_weight=20,
    friction_angle=45,
    cohesion=2,
    depth_to_bottom=2
)

# material can also be defined with positional arguments, if the user can remember
# the order of required parameters.
m2 = Material(20, 30, 2, 5)

# the created material objects can then be assigned to the model.
# The same depth to bottom cant be specified for two different materials and an
# error will be raised if this happens
s.set_materials(m1,m2)

# define uniform load objects with magnitude (kPa), offset (m) from the crest of the slope
# length of the load (m) (if greater than length slope or None then assumed continuous).
u1 = Udl(magnitude = 100, offset = 2, length = 1)

# by default offset = 0 (m) and length = None.
u2 = Udl(magnitude = 20)

# assign uniform loads to model 
s.set_udls(u1, u2)

# define line load, similiar to Udl except there is no length parameter and magnitude is in units (kN/m)
p1 = LineLoad(magnitude = 10, offset = 3)

# assign line loads to slope
s.set_lls(p1)

# Set water table if required. If None then not considered, by default no water table.
s.set_water_table(4)

# set limits on the slope failure search zone
s.set_analysis_limits(s.get_top_coordinates()[0] - 5, s.get_bottom_coordinates()[0] + 5)

# run calculations on the created slope
s.analyse_slope()

# print the critical FOS for the slope
print('fos:',s.get_min_FOS())

# plot the critical failure surface
# fig_1 = s.plot_critical()
# fig_1.show()

# plot all failure planes with a FOS below 2
fig_2 = s.plot_all_planes(max_fos=2)
fig_2.show()


# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./readme_example_plot_critical.png")
# fig_2.write_image("./readme_example_plot_all_maxfos2.png")
# Out:
# fos: 1.5437888294282964
# 100%|██████████| 975/975 [00:00<00:00, 13317.64it/s]

# %%
# lets say i want to see how close i can move my 100 kPa UDL
# while keeping the FOS above 1.4

# remove udl object load from slope
s.remove_udls(u1)

# if we didnt have the object we could remove all and readd the
# other udl object
s.remove_udls(remove_all=True)
s.set_udls(u2)

# now lets add the udl again but this time set the load as 'dynamic'
# for all loads and materials we also have the option to set the color ourselves
# lets try set the color as 'purple'
s.set_udls(
    Udl(magnitude=100, length=1, offset=2, dynamic_offset=True, color='purple')
)

# note that if we try to look at the minimum FOS now we get nothing.
# if we change anything about the model all previosu calculations are thrown out.
s.print_dynamic_results()

# lets run a dynamic analysis to see what the offset would be:
s.analyse_dynamic(critical_fos=1.4)
s.print_dynamic_results()

# note that values can be retrieved as a dictionary with s.get_dynamic_results()

fig_3 = s.plot_critical()
fig_3.show()

fig_3.write_image("./readme_example_plot_dynamic.png")
# Out:
# Offset: 0.000 m, FOS: 1.282
# Offset: 0.701 m, FOS: 1.395
# Offset: 0.726 m, FOS: 1.400
# Offset: 0.937 m, FOS: 1.440
# Offset: 9.382 m, FOS: 1.656
# Offset: 2.965 m, FOS: 1.656
# <div>                            <div id="a26c2885-08d6-4e16-8789-deefe791c661" class="plotly-graph-div" style="height:1200px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a26c2885-08d6-4e16-8789-deefe791c661")) {                    Plotly.newPlot(                        "a26c2885-08d6-4e16-8789-deefe791c661",                        [{"mode":"lines","name":"","x":[0,0,10.392304845413264,15.588457268119896,25.98076211353316,25.98076211353316,0],"y":[0,12.99038105676658,12.99038105676658,9.99038105676658,9.99038105676658,0,0],"type":"scatter"},{"fill":"toself","fillcolor":"#efa59c","hovertemplate":"","meta":[20,2,45,""],"mode":"lines","name":"\u003cbr\u003e\u03b3: 20 kN\u002fm3\u003cbr\u003ec: 2 kPa\u003cbr\u003e\u03d5: 45 degrees","x":[0,10.392304845413264,13.85640646055102,0],"y":[12.99038105676658,12.99038105676658,10.99038105676658,10.99038105676658],"type":"scatter"},{"fill":"toself","fillcolor":"#77e1ca","hovertemplate":"","meta":[20,2,30,""],"mode":"lines","name":"\u003cbr\u003e\u03b3: 20 kN\u002fm3\u003cbr\u003ec: 2 kPa\u003cbr\u003e\u03d5: 30 degrees","x":[0,13.85640646055102,15.588457268119896,25.98076211353316,25.98076211353316,0],"y":[10.99038105676658,10.99038105676658,9.99038105676658,9.99038105676658,0,0],"type":"scatter"},{"line":{"color":"blue","width":4},"mode":"lines","name":"","x":[0,25.98076211353316],"y":[8.99038105676658,8.99038105676658],"type":"scatter"},{"hovertemplate":"","line":{"color":"#a6cc00"},"mode":"lines","name":"","texttemplate":"","x":[8.676,8.796,8.922,9.054,9.193,9.338,9.488,9.645,9.807,9.974,10.147,10.325,10.507,10.694,10.885,11.08,11.279,11.482,11.687,11.896,12.108,12.322,12.539,12.758,12.978,13.2,13.423,13.647,13.872,14.097,14.323,14.548,14.773,14.997,15.22,15.442,15.588457268119894,14.21,8.665362191777765,8.676],"y":[12.973,12.782,12.595,12.413,12.235,12.062,11.895,11.733,11.576,11.426,11.281,11.142,11.01,10.884,10.764,10.651,10.546,10.447,10.355,10.271,10.194,10.124,10.062,10.007,9.961,9.921,9.89,9.867,9.851,9.843,9.843,9.851,9.867,9.89,9.921,9.961,9.99038105676658,16.298,12.99038105676658,12.973],"type":"scatter"},{"hovertemplate":"Centre: (14.210, 16.298)\u003cbr\u003eRadius: 6.456\u003cbr\u003eFOS: 1.400","mode":"lines+text","name":"","text":["1.400"],"textfont":{"color":"#a6cc00","family":"sans serif","size":20},"textposition":"top right","texttemplate":"%{text}","x":[14.21],"y":[16.298],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222 ...

# %%
s.remove_individual_planes()

for r in [9,10,11]:
    s.add_single_circular_plane(
        c_x = 13.7,
        c_y = 17.02,
        radius = r,
    )

s.analyse_slope()

fig = s.plot_all_planes()
fig.show()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 1872.46it/s]
# <div>                            <div id="d359ac92-b436-468e-90ec-5baa4aecc871" class="plotly-graph-div" style="height:1200px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d359ac92-b436-468e-90ec-5baa4aecc871")) {                    Plotly.newPlot(                        "d359ac92-b436-468e-90ec-5baa4aecc871",                        [{"mode":"lines","name":"","x":[0,0,10.392304845413264,15.588457268119896,25.98076211353316,25.98076211353316,0],"y":[0,12.99038105676658,12.99038105676658,9.99038105676658,9.99038105676658,0,0],"type":"scatter"},{"fill":"toself","fillcolor":"#efa59c","hovertemplate":"","meta":[20,2,45,""],"mode":"lines","name":"\u003cbr\u003e\u03b3: 20 kN\u002fm3\u003cbr\u003ec: 2 kPa\u003cbr\u003e\u03d5: 45 degrees","x":[0,10.392304845413264,13.85640646055102,0],"y":[12.99038105676658,12.99038105676658,10.99038105676658,10.99038105676658],"type":"scatter"},{"fill":"toself","fillcolor":"#77e1ca","hovertemplate":"","meta":[20,2,30,""],"mode":"lines","name":"\u003cbr\u003e\u03b3: 20 kN\u002fm3\u003cbr\u003ec: 2 kPa\u003cbr\u003e\u03d5: 30 degrees","x":[0,13.85640646055102,15.588457268119896,25.98076211353316,25.98076211353316,0],"y":[10.99038105676658,10.99038105676658,9.99038105676658,9.99038105676658,0,0],"type":"scatter"},{"line":{"color":"blue","width":4},"mode